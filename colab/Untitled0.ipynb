# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13335188 kB
# MemFree:        10840988 kB
# MemAvailable:   12510244 kB
# Buffers:           69416 kB
# Cached:          1760456 kB
# SwapCached:            0 kB
# Active:           686108 kB
# Inactive:        1562888 kB
# Active(anon):     399480 kB
# Inactive(anon):      312 kB
# Active(file):     286628 kB
# Inactive(file):  1562576 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               560 kB
# Writeback:             0 kB
# AnonPages:        419276 kB
# Mapped:           216312 kB
# Shmem:               848 kB
# Slab:             152404 kB
# SReclaimable:     122092 kB
# SUnreclaim:        30312 kB
# KernelStack:        3456 kB
# PageTables:         5320 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6667592 kB
# Committed_AS:    2727328 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# ...

# %%
# !pwd
# Out:
# /content
